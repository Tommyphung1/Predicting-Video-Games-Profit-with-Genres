# %%
games_df = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')
games_df.loc[games_df.Name.isna()]    ## Games with no name?
games_df.dropna(subset= ['Name'], inplace = True)
games_df

# %%
pd.read_csv('Airbnb_Texas_Rentals.csv')
# Out:
#        Unnamed: 0 average_rate_per_night bedrooms_count         city  \
# 0               1                    $27              2       Humble
# 1               2                   $149              4  San Antonio
# 2               3                    $59              1      Houston
# 3               4                    $60              1        Bryan
# 4               5                    $75              2   Fort Worth
# ...           ...                    ...            ...          ...
# 18254       18255                    $60              1       Dallas
# 18255       18256                    $99              2  San Antonio
# 18256       18257                    $13              1       Dallas
# 18257       18258                    $65              2  San Antonio
# 18258       18259                    $75              1  San Antonio
#
#       date_of_listing                                        description  \
# ...

# %%
horror_df = pd.read_csv('IMDB Horror movies.csv')

# %%
horror_df.isna().sum()
# Out:
# Title                   0
# Genres                  1
# Release Date            0
# Release Country         0
# Movie Rating         1877
# Review Rating         252
# Movie Run Time        544
# Plot                    1
# Cast                   14
# Language               71
# Filming Locations    1232
# Budget               2094
# dtype: int64

# %%
games_df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64
